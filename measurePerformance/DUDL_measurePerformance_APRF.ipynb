# %% [markdown]
# # COURSE: A deep understanding of deep learning
# ## SECTION: Measuring model performance
# ### LECTURE: ARPF in code
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/deeplearning_x/?couponCode=202305

# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt

# update default font size
import matplotlib
matplotlib.rcParams.update({'font.size':18})

# %% [markdown]
# # Run the experiments

# %%
## run experiment

# number of 'trials' in the experiment
N = 50 # actual trials is 2N

# number of experiment repetitions
numExps = 10000

# initialize
accuracy  = np.zeros(numExps)
precision = np.zeros(numExps)
recall    = np.zeros(numExps)
F1score   = np.zeros(numExps)


### run the experiment!
for expi in range(numExps):
    
  # generate data
  TP = np.random.randint(1,N)  # true positives,  aka hits
  FN = N-TP                    # false negatives, aka misses
  TN = np.random.randint(1,N)  # true negatives,  aka correct rejections
  FP = N-TN                    # false positives, aka false alarms
  

  ### the four performance measures discussed in lecture

  # accuracy
  accuracy[expi]  = (TP+TN) / (2*N)

  # precision
  precision[expi] = TP / (TP+FP)

  # recall
  recall[expi]    = TP / (TP+FN)

  # Fscore
  F1score[expi]   = TP / (TP+(FP+FN)/2)

# %%
## let's see how they relate to each other!

fig,ax = plt.subplots(1,2,figsize=(18,6))

ax[0].scatter(accuracy,F1score,s=5,c=precision)
ax[0].plot([0,1],[.5,.5],'k--',linewidth=.5)
ax[0].plot([.5,.5],[0,1],'k--',linewidth=.5)
ax[0].set_xlabel('Accuracy')
ax[0].set_ylabel('F1-score')
ax[0].set_title('F1-Accuracy by precision')


ax[1].scatter(accuracy,F1score,s=5,c=recall)
ax[1].plot([0,1],[.5,.5],'k--',linewidth=.5)
ax[1].plot([.5,.5],[0,1],'k--',linewidth=.5)
ax[1].set_xlabel('Accuracy')
ax[1].set_ylabel('F1-score')
ax[1].set_title('F1-Accuracy by recall')

plt.show()

# %% [markdown]
# - Cada punto en los gráficos representa un experimento diferente.
# - En ambos gráficos se muestra la relación entre la precisión en el eje x y el F1-score en el eje y.
# - En el primer gráfico, el color de los puntos indica la precisión y en el segundo gráfico el color de los puntos indica el recall.
# - Ambos gráficos muestran una tendencia ascendente, lo que indica que a medida que la precisión aumenta, también lo hace el F1-score (hay una relación positiva entre la precisión y el F1-score, o correlación positiva).
# - Sin embargo, esa correlación no es perfecta, ya que hay puntos con alta precisión y bajo F1-score, y viceversa (por ejemplo, para una Accuracy de 0.2, hay puntos con F1-score de 0.3 mientras que para una Accuracy de 0.4 hay puntos con F1-score de 0.1, es decir, hay una correlación negativa en estos casos). En promedio, la correlación es positiva.
# - En el primer gráfico, se observa que los valores altos de Accuracy se deben a valores altos de precisión, mientras que en el segundo, los valores altos de F1-score se deben a valores altos de recall.

# %% [markdown]
# Reminder of the three metrics:
# ![APR_summary.png ><](data:image/png;base64,...)
